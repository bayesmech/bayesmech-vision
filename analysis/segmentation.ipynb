# %%
import os
import sys
from pathlib import Path

_project_root = Path(os.getcwd()).parent
sys.path.append(_project_root.as_posix())

os.listdir(_project_root)
print(sys.path)
# from proto.segmentation_pb2 import SegmentationResponse
# from server.streamlog.protoio import ProtoIO
# Out:
# ['/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/home/animesh/Code/Projects/bayesmech-vision/server/.venv/lib/python3.12/site-packages', '/home/animesh/Code/Projects/bayesmech-vision/server', PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision'), PosixPath('/home/animesh/Code/Projects/bayesmech-vision')]

# %%
file = project_root / "recordings" / "arstream_20260221_172747.seg.pb"
data = ProtoIO(SegmentationResponse).read_file(file)
